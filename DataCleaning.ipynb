# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("/content/Data Cleaning_part1_dataset_movie scores (1).csv")

# %%
df

# %% [markdown]
# Gives boolean putputs for null values

# %%
df.isnull()
# Out:
#    first_name  last_name    age  Gender  pre_movie_score  post_movie_score
# 0       False      False  False   False            False             False
# 1        True       True   True    True             True              True
# 2       False      False  False   False             True              True
# 3       False      False  False   False            False             False
# 4       False      False  False   False            False             False

# %%
df.notnull()
# Out:
#    first_name  last_name    age  Gender  pre_movie_score  post_movie_score
# 0        True       True   True    True             True              True
# 1       False      False  False   False            False             False
# 2        True       True   True    True            False             False
# 3        True       True   True    True             True              True
# 4        True       True   True    True             True              True

# %%
df['first_name']
# Out:
# 0     Root
# 1      NaN
# 2    Stark
# 3    Sofie
# 4     Emma
# Name: first_name, dtype: object

# %% [markdown]
# display the name odf the student who has not given the pre movie scores

# %%
df[df['first_name'].notnull()&df['pre_movie_score'].isnull()]
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 2      Stark      Mike  48.0      m              NaN               NaN

# %% [markdown]
# Display the gender of people who have not given the pre movie score

# %%
df[df['pre_movie_score'].isnull()&df['Gender'].notnull()]
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 2      Stark      Mike  48.0      m              NaN               NaN

# %%
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1        NaN       NaN   NaN    NaN              NaN               NaN
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(*, axis: 'Axis' = 0, how: 'AnyAll | lib.NoDefault' = <no_default>, thresh: 'int | lib.NoDefault' = <no_default>, subset: 'IndexLabel | None' = None, inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
# ...

# %% [markdown]
# .sum() gives the column wise count of null values present in each column

# %%
df.isna().sum()
# Out:
# first_name          1
# last_name           1
# age                 1
# Gender              1
# pre_movie_score     2
# post_movie_score    2
# dtype: int64

# %% [markdown]
# .sum().sum() gives the total number of null values in the entire data set

# %%
df.isna().sum().sum()
# Out:
# 8

# %% [markdown]
# Dropping the rows that have null values

# %%
df1 = df.dropna(axis=0)

# %%
df1
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# Drops all the columns that have null values

# %%
df2 = df.dropna(axis=1)

# %%
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# Threshint- Tolerence limit of number of null values

# %%
df4=df.dropna(thresh=2)

# %%
df4
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# All the missing/nan values get replaced by 1

# %%
df.fillna(10)
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1         10        10  10.0     10             10.0              10.0
# 2      Stark      Mike  48.0      m             10.0              10.0
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# Fills all nan values of age column by 50.

# %%
df['age']=df['age'].fillna(50)

# %%
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1        NaN       NaN  50.0    NaN              NaN               NaN
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
df= pd.read_csv("/content/Data Cleaning_part1_dataset_movie scores (1).csv")

# %%
df['first_name']=df['first_name'].fillna("pooja")

# %%
df['last_name']=df['last_name'].fillna("kamat")

# %%
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1      pooja     kamat   NaN    NaN              NaN               NaN
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# Mean of the pre movies score column was calculate and nan value of the column was updated to the mean

# %%
df['pre_movie_score'].mean()
# Out:
# 7.0

# %%
df['pre_movie_score']=df['pre_movie_score'].fillna(df['pre_movie_score'].mean())
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1      pooja     kamat   NaN    NaN              7.0               NaN
# 2      Stark      Mike  48.0      m              7.0               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# All nan values are replaced by the median in the age column

# %%
df['age']=df['age'].fillna(df['age'].median())
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1      pooja     kamat  43.5    NaN              7.0               NaN
# 2      Stark      Mike  48.0      m              7.0               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
df['post_movie_score']=df['post_movie_score'].fillna(df['post_movie_score'].mean())
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0          9.000000
# 1      pooja     kamat  43.5    NaN              7.0          8.333333
# 2      Stark      Mike  48.0      m              7.0          8.333333
# 3      Sofie    Miller  39.0      f              7.0          8.000000
# 4       Emma       Roy  84.0      f              6.0          8.000000

# %% [markdown]
# Part 2

# %%
dz=pd.read_csv("/content/Data Cleaning_part1_dataset_movie scores (1).csv")

# %%
dz
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1        NaN       NaN   NaN    NaN              NaN               NaN
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
dz.mean(numeric_only=True)
# Out:
# age                 51.750000
# pre_movie_score      7.000000
# post_movie_score     8.333333
# dtype: float64

# %%
dz.fillna(dz.mean(numeric_only=True))
# Out:
#   first_name last_name    age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.00      m              8.0          9.000000
# 1        NaN       NaN  51.75    NaN              7.0          8.333333
# 2      Stark      Mike  48.00      m              7.0          8.333333
# 3      Sofie    Miller  39.00      f              7.0          8.000000
# 4       Emma       Roy  84.00      f              6.0          8.000000

# %%
dz.fillna(dz.median(numeric_only=True))
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1        NaN       NaN  43.5    NaN              7.0               8.0
# 2      Stark      Mike  48.0      m              7.0               8.0
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0
